# %% [markdown]
# #                         # Welcome To Python

# %% [markdown]
# Learning Python Basics

# %%
2+2
# Out:
# 4

# %%
3-2
# Out:
# 1

# %%
3*2
# Out:
# 6

# %%
10/2
# Out:
# 5.0

# %% [markdown]
# addition

# %%
4+4
# Out:
# 8

# %% [markdown]
#  floor division

# %%
10//2
# Out:
# 5

# %%
10%2
# Out:
# 0

# %%
11%2
# Out:
# 1

# %%
15%2
# Out:
# 1

# %% [markdown]
# **=power

# %% [markdown]
# power

# %%
2**2
# Out:
# 4

# %%
2**3
# Out:
# 8

# %%
4**2
# Out:
# 16

# %%
7**2
# Out:
# 49

# %%
8**3
# Out:
# 512

# %% [markdown]
# square root

# %%
25**.5
# Out:
# 5.0

# %%
64**.5
# Out:
# 8.0

# %% [markdown]
# cube root

# %%
625**(1/3)
# Out:
# 8.549879733383484

# %%
8**(1/3)
# Out:
# 2.0

# %%
working with variables

a=10
b=5
# Out:
#   File "<ipython-input-55-9eb6dfe0ded2>", line 1
#     working with variables
#             ^
# SyntaxError: invalid syntax

# %%
a
# Out:
# 10

# %%
b=5

# %%
b
# Out:
# 5

# %%
a+b
# Out:
# 15

# %%
a-b
# Out:
# 5

# %%
a*b
# Out:
# 50

# %%
c=a+b

# %%
c
# Out:
# 15

# %%
d=a-b

# %%
d
# Out:
# 5

# %%
print("c=")
# Out:
# c=

# %%
print("c=",c)
# Out:
# c= 15

# %%
print("d=",d)
# Out:
# d= 5

# %% [markdown]
# Area of rectangle

# %%
length=70
breadth=5

area=length*breadth

area
# Out:
# 350

# %%
print('area of rectangle=',area)
# Out:
# area of rectangle= 350

# %% [markdown]
# Boolean Operations

# %% [markdown]
# True and False

# %%
2>4
# Out:
# False

# %%
8>3
# Out:
# True

# %%
16<48
# Out:
# True

# %% [markdown]
# Comparison operator

# %%
12==10
# Out:
# False

# %%
10==10
# Out:
# True

# %% [markdown]
# not equals to operator(!)

# %%
5!=10
# Out:
# True

# %%
10!=10
# Out:
# False

# %%
300!=100
# Out:
# True
